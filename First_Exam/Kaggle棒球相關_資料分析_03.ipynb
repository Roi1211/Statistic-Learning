# %%
import pandas as pd
import numpy  as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("data/train.csv")
test  = pd.read_csv("data/test.csv")
df    = pd.concat([train,test],axis=0, sort=False)
df.head()
# Out:
#    id   playerID  yearID  stint teamID lgID   W  L   G  GS  ...   WP  HBP  \
# 0   0  nelsoge01    1986      1    CHA   AL   6  6  54   1  ...  3.0  3.0
# 1   1  moyerja01    1997      1    SEA   AL  17  5  30  30  ...  3.0  7.0
# 2   2  thompbr01    2008      1    SLN   NL   6  3  26   6  ...  2.0  3.0
# 3   3  powerte01    1986      1    CIN   NL  10  6  56  10  ...  5.0  1.0
# 4   4  osunaan01    2003      1    NYA   AL   2  5  48   0  ...  3.0  2.0
#
#     BK    BFP    GF   R  SH  SF  GIDP  salary_next_year
# 0  0.0  488.0  26.0  52 NaN NaN   NaN          365000.0
# 1  0.0  787.0   0.0  82 NaN NaN   NaN         2000000.0
# 2  0.0  273.0  10.0  38 NaN NaN   NaN          650000.0
# 3  1.0  537.0  30.0  59 NaN NaN   NaN          500000.0
# 4  0.0  232.0  16.0  22 NaN NaN   NaN          750000.0
#
# [5 rows x 32 columns]

# %%
# 檢查 DataFrame 空缺值的狀態
def na_check(df_data):
    data_na = (df_data.isnull().sum() / len(df_data)) * 100
    data_na = data_na.drop(data_na[data_na == 0].index).sort_values(ascending=False)
    missing_data = pd.DataFrame({'Missing Ratio' :data_na})
    display(missing_data.head(10))
na_check(df)
# Out:
#                   Missing Ratio
# GIDP                 100.000000
# SF                   100.000000
# SH                   100.000000
# BAOpp                 39.050453
# salary_next_year      15.000676
# BK                     0.013526
# HBP                    0.013526
# WP                     0.013526
# IBB                    0.013526

# %%
# 去除大量遺失數據
df = df.drop(['GIDP','SF','SH'],axis=1)
df.shape
# Out:
# (7393, 29)

# %%
mask = (df['BK'].isnull() | df['HBP'].isnull() | df['WP'].isnull() | df['IBB'].isnull())
print("極少量遺失數據數量=",mask.sum())
df.iloc[mask.values]
print("推測因沒上場幾次，所以應該都為零")
df.iloc[mask.values] = df.iloc[mask.values].fillna(0)
na_check(df)
# Out:
# 極少量遺失數據數量= 1
# 推測因沒上場幾次，所以應該都為零
#                   Missing Ratio
# BAOpp                 39.050453
# salary_next_year      14.987150

# %%
# fill BAOpp
from xgboost import XGBRegressor
from sklearn import metrics  
from sklearn.model_selection import train_test_split

# %%
other_params = {'learning_rate': 0.1, 'n_estimators': 500, 'max_depth': 5, 'min_child_weight': 1, 'seed': 0,
'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0, 'reg_alpha': 0, 'reg_lambda': 1}
model = XGBRegressor(**other_params)

data_x = df.iloc[:,6:28]
data_y = data_x['BAOpp']
data_x.drop('BAOpp', axis=1)

train_x = data_x[data_y.notna()]
test_x  = data_x[data_y.isna()]
train_y = data_y[data_y.notna()]

train_X, test_X, train_Y, test_Y = train_test_split(train_x, train_y, test_size=0.6)

model.fit(train_X, train_Y)
predict_train_y= model.predict(train_X)
score_train = metrics.r2_score(train_Y, predict_train_y)
print('train score=', score_train)
predict_test_y= model.predict(test_X)
score_test = metrics.r2_score(test_Y, predict_test_y)
print('test score=', score_test)
# Out:
# C:\Users\Company\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [17:46:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# train score= 0.9999793917530111
# test score= 0.9980240579899189

# %%
df['BAOpp'][df['BAOpp'].isna().values]=model.predict(test_x)
df['BAOpp'][df['BAOpp']<=0]=0
# Out:
# C:\Users\Company\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Company\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
na_check(df)
# Out:
#                   Missing Ratio
# salary_next_year       14.98715

# %% [markdown]
# # -----------------------
# # 先分析object數據

# %%
df.columns[df.dtypes == 'object']
# Out:
# Index(['playerID', 'teamID', 'lgID'], dtype='object')

# %%
#df['playerName'] = df['playerID'].apply(lambda x: x[:-2])
#df['playerIDint']   = df['playerID'].apply(lambda x: int(x[-2:]))
#print(len(df['playerIDint'].unique()),",   ",df['playerIDint'].unique())
#print(len(df['playerName'].unique()),",   ",len(df['playerID'].unique()),",   ",len(df))
#print("\n-----\nplayerName_top10\n-----\n", df['playerName'].value_counts().head(10))
print("\n-----\nplayerID_top10\n-----\n", df['playerID'].value_counts().head(10))
print("\n-----\nplayerID_top10\n-----\n", df['playerID'].value_counts().tail(10))
# Out:
# -----
# playerID_top10
# -----
#  moyerja01    24
# glavito02    21
# johnsra05    20
# maddugr01    20
# clemero02    20
# gordoto01    19
# smoltjo01    19
# rogerke01    19
# wellsda01    19
# francjo01    19
# Name: playerID, dtype: int64
#
# -----
# playerID_top10
# -----
#  gonzagi01    2
# johnsda05    2
# cangejo01    2
# baileco01    2
# staufti01    2
# lynched01    2
# chacigu01    2
# lucasga01    2
# frankwa01    2
# anderal02    2
# Name: playerID, dtype: int64

# %%
mask = (df['playerID']=='moyerja01').values
df.iloc[mask,:].sort_values(by='yearID')
# Out:
#         id   playerID  yearID  stint teamID lgID   W   L   G  GS  ...  \
# 1498  1498  moyerja01    1986      1    CHN   NL   7   4  16  16  ...
# 1402  1402  moyerja01    1987      1    CHN   NL  12  15  35  33  ...
# 5856  5856  moyerja01    1988      1    CHN   NL   9  15  34  30  ...
# 6221  6221  moyerja01    1989      1    TEX   AL   4   9  15  15  ...
# 2001  2001  moyerja01    1990      1    TEX   AL   2   6  33  10  ...
# 1675  1675  moyerja01    1991      1    SLN   NL   0   5   8   7  ...
# 1045  1045  moyerja01    1993      1    BAL   AL  12   9  25  25  ...
# 4367  4367  moyerja01    1994      1    BAL   AL   5   7  23  23  ...
# 4784  4784  moyerja01    1995      1    BAL   AL   8   6  27  18  ...
# 544   6828  moyerja01    1996      1    BOS   AL   7   1  23  10  ...
# 1        1  moyerja01    1997      1    SEA   AL  17   5  30  30  ...
# 782    782  moyerja01    1998      1    SEA   AL  15   9  34  34  ...
# 3251  3251  moyerja01    1999      1    SEA   AL  14   8  32  32  ...
# 5453  5453  moyerja01    2000      1    SEA   AL  13  10  26  26  ...
# 2618  2618  moyerja01    2001      1    SEA   AL  20   6  33  33  ...
# 204   6488  moyerja01    2002      1    SEA   AL  13   8  34  34  ...
# 4427  4427  moyerja01    2003      1    SEA   AL  21   7  33  33  ...
# 4633  4633  moyerja01    2004      1    SEA   AL   7  13  34  33  ...
# 1439  1439  moyerja01    2005      1    SEA   AL  13   7  32  32  ...
# 10      10  moyerja01    2006      1    SEA   AL   6  12  25  25  ...
# 4815  4815  moyerja01    2007      1    PHI   NL  14  12  33  33  ...
# 1826  1826  moyerja01    2008      1    PHI   NL  16   7  33  33  ...
# 3048  3048  moyerja01    2009      1    PHI   NL  12  10  30  25  ...
# 5273  5273  moyerja01    2010      1    PHI   NL   9   9  19  19  ...
#
#          BAOpp   ERA  IBB    WP   HBP   BK    BFP   GF    R  salary_next_year
# 1498  0.310000  5.05  1.0   3.0   3.0  3.0  395.0  0.0   52           70000.0
# 1402  0.270000  5.10  9.0  11.0   5.0  2.0  899.0  1.0  127          142500.0
# 5856  0.270000  3.48  7.0   4.0   4.0  0.0  855.0  1.0   84          205000.0
# 6221  0.280000  4.86  0.0   1.0   2.0  0.0  337.0  0.0   51          340000.0
# 2001  0.290000  4.66  4.0   1.0   4.0  0.0  447.0  6.0   59          200000.0
# 1675  0.310000  5.74  0.0   2.0   1.0  1.0  142.0  1.0   21          200000.0
# 1045  0.260000  3.43  2.0   1.0   6.0  1.0  630.0  0.0   63          725000.0
# 4367  0.260000  4.77  3.0   1.0   2.0  0.0  631.0  0.0   81         1100000.0
# 4784  0.250000  5.21  0.0   0.0   3.0  0.0  483.0  3.0   70          825000.0
# 544   0.270000  4.50  2.0   2.0   1.0  1.0  405.0  1.0   50               NaN
# 1     0.250000  3.86  2.0   3.0   7.0  0.0  787.0  0.0   82         2000000.0
# 782   0.003373  3.53  2.0   3.0  10.0  1.0  974.0  0.0   99         2300000.0
# 3251  0.000000  3.87  1.0   3.0   9.0  0.0  945.0  0.0  108         6000000.0
# 5453  0.000000  5.49  2.0   4.0   3.0  1.0  678.0  0.0  103         6500000.0
# 2618  0.000000  3.43  4.0   1.0  10.0  0.0  851.0  0.0   84         6500000.0
# 204   0.000000  3.32  4.0   3.0   9.0  0.0  931.0  0.0   89               NaN
# 4427  0.240000  3.27  3.0   0.0   8.0  0.0  897.0  0.0   83         7000000.0
# 4633  0.270000  5.21  3.0   1.0  11.0  0.0  888.0  1.0  127         8000000.0
# 1439  0.000000  4.28  2.0   3.0   8.0  0.0  868.0  0.0   99         5500000.0
# 10    0.001989  4.39  3.0   3.0   3.0  1.0  685.0  0.0   85         6500000.0
# 4815  0.000179  5.01  3.0   2.0   5.0  0.0  867.0  0.0  118         6000000.0
# 1826  0.000000  3.71  4.0   3.0  11.0  0.0  841.0  0.0   85         6500000.0
# 3048  0.001107  4.94  1.0   1.0  10.0  1.0  699.0  1.0   91         8000000.0
# 5273  0.001776  4.84  0.0   0.0   6.0  0.0  460.0  0.0   64         1100000.0
#
# [24 rows x 29 columns]

# %%
mask = (df['playerID']=='glavito02').values
df.iloc[mask,:].sort_values(by='yearID')
# Out:
#         id   playerID  yearID  stint teamID lgID   W   L   G  GS  ...  \
# 1436  1436  glavito02    1987      1    ATL   NL   2   4   9   9  ...
# 4982  4982  glavito02    1988      1    ATL   NL   7  17  34  34  ...
# 662    662  glavito02    1989      1    ATL   NL  14   8  29  29  ...
# 5084  5084  glavito02    1990      1    ATL   NL  10  12  33  33  ...
# 4140  4140  glavito02    1991      1    ATL   NL  20  11  34  34  ...
# 731   7015  glavito02    1992      1    ATL   NL  20   8  33  33  ...
# 635    635  glavito02    1993      1    ATL   NL  22   6  36  36  ...
# 4584  4584  glavito02    1994      1    ATL   NL  13   9  25  25  ...
# 3278  3278  glavito02    1995      1    ATL   NL  16   7  29  29  ...
# 962    962  glavito02    1996      1    ATL   NL  15  10  36  36  ...
# 704    704  glavito02    1997      1    ATL   NL  14   7  33  33  ...
# 2477  2477  glavito02    1998      1    ATL   NL  20   6  33  33  ...
# 5660  5660  glavito02    1999      1    ATL   NL  14  11  35  35  ...
# 4707  4707  glavito02    2000      1    ATL   NL  21   9  35  35  ...
# 2671  2671  glavito02    2001      1    ATL   NL  16   7  35  35  ...
# 5384  5384  glavito02    2002      1    ATL   NL  18  11  36  36  ...
# 2488  2488  glavito02    2003      1    NYN   NL   9  14  32  32  ...
# 2490  2490  glavito02    2004      1    NYN   NL  11  14  33  33  ...
# 1931  1931  glavito02    2005      1    NYN   NL  13  13  33  33  ...
# 3614  3614  glavito02    2006      1    NYN   NL  15   7  32  32  ...
# 1087  7371  glavito02    2007      1    NYN   NL  13   8  34  34  ...
#
#          BAOpp   ERA   IBB    WP  HBP   BK     BFP   GF    R  salary_next_year
# 1436  0.270000  5.54   4.0   1.0  3.0  1.0   238.0  0.0   34           65000.0
# 4982  0.270000  4.56   7.0   2.0  8.0  2.0   844.0  0.0  111          117500.0
# 662   0.240000  3.68   3.0   2.0  2.0  0.0   766.0  0.0   88          285000.0
# 5084  0.280000  4.28  10.0   8.0  1.0  1.0   929.0  0.0  111          697500.0
# 4140  0.220000  2.55   6.0  10.0  2.0  2.0   989.0  0.0   83         2975000.0
# 731   0.230000  2.76   7.0   5.0  2.0  0.0   919.0  0.0   81               NaN
# 635   0.250000  3.20   7.0   4.0  2.0  0.0  1014.0  0.0   91         4750000.0
# 4584  0.250000  3.97  10.0   8.0  1.0  1.0   731.0  0.0   76         4750000.0
# 3278  0.240000  3.08   0.0   3.0  5.0  0.0   822.0  0.0   76         5350000.0
# 962   0.220000  2.98   7.0   4.0  0.0  0.0   994.0  0.0   91         5050000.0
# 704   0.220000  2.96   9.0   3.0  4.0  0.0   970.0  0.0   86         7000000.0
# 2477  0.001027  2.47   2.0   3.0  2.0  0.0   934.0  0.0   67         7000000.0
# 5660  0.000000  4.12  14.0   2.0  4.0  0.0  1023.0  0.0  115         9463237.0
# 4707  0.000000  3.40   6.0   0.0  4.0  0.0   992.0  0.0  101         9500000.0
# 2671  0.000661  3.57  10.0   2.0  2.0  0.0   929.0  0.0   92         8623700.0
# 5384  0.000000  2.96   8.0   2.0  8.0  0.0   936.0  0.0   85        11000000.0
# 2488  0.280000  4.52   7.0   2.0  2.0  0.0   791.0  0.0   94        10765608.0
# 2490  0.250000  3.60  10.0   0.0  0.0  0.0   904.0  0.0   94        10765608.0
# 1931  0.001173  3.53   5.0   1.0  3.0  0.0   901.0  0.0   88         9993640.0
# 3614  0.000000  3.82   7.0   1.0  6.0  0.0   842.0  0.0   94         7500000.0
# 1087  0.000000  4.45   2.0   2.0  4.0  0.0   855.0  0.0  102               NaN
#
# [21 rows x 29 columns]

# %%
mask = (df['playerID']=='latosma01').values
df.iloc[mask,:].sort_values(by='yearID')
# Out:
#         id   playerID  yearID  stint teamID lgID   W   L   G  GS  ...  \
# 774    774  latosma01    2010      1    SDN   NL  14  10  31  31  ...
# 2522  2522  latosma01    2011      1    SDN   NL   9  14  31  31  ...
#
#          BAOpp   ERA  IBB   WP  HBP   BK    BFP   GF   R  salary_next_year
# 774   0.005729  2.92  3.0  5.0  2.0  1.0  748.0  0.0  63          460700.0
# 2522  0.000000  3.47  3.0  5.0  1.0  0.0  799.0  0.0  82          550000.0
#
# [2 rows x 29 columns]

# %%
NewColumns = ['years','firstsalary','firstyear', 'salary_the_year', 'totalyears']
for t in NewColumns: df[t] = np.nan

def year(dfx):
    global df
    N = len(dfx)
    for ix,i in  enumerate(dfx.sort_values(by='yearID')['id']):  #dfx.sort_values(by='yearID')['id']
        df['years'].iloc[i]       =  dfx['yearID'].iloc[ix]-dfx['yearID'].min()
        df['firstsalary'].iloc[i] =  dfx['salary_next_year'][dfx['yearID']==dfx['yearID'].min()].values[0]    
        df['firstyear'].iloc[i]   =  dfx['yearID'].min()
        df['totalyears'].iloc[i]  =  N
        if ix==0: 
            df['salary_the_year'].iloc[i] = dfx['salary_next_year'][dfx['yearID']==dfx['yearID'].min()].values[0]   
        else:
            df['salary_the_year'].iloc[i] = dfx.sort_values(by='yearID')['salary_next_year'].iloc[ix-1]
        
    return dfx['yearID']-dfx['yearID'].min()

df.groupby('playerID').apply(year)
df.head()
# Out:
#    id   playerID  yearID  stint teamID lgID   W  L   G  GS  ...   BK    BFP  \
# 0   0  nelsoge01    1986      1    CHA   AL   6  6  54   1  ...  0.0  488.0
# 1   1  moyerja01    1997      1    SEA   AL  17  5  30  30  ...  0.0  787.0
# 2   2  thompbr01    2008      1    SLN   NL   6  3  26   6  ...  0.0  273.0
# 3   3  powerte01    1986      1    CIN   NL  10  6  56  10  ...  1.0  537.0
# 4   4  osunaan01    2003      1    NYA   AL   2  5  48   0  ...  0.0  232.0
#
#      GF   R  salary_next_year  years  firstsalary  firstyear  salary_the_year  \
# 0  26.0  52          365000.0    4.0     240000.0     1985.0         240000.0
# 1   0.0  82         2000000.0   15.0      70000.0     1986.0              NaN
# 2  10.0  38          650000.0    0.0     400000.0     2006.0         414000.0
# 3  30.0  59          500000.0    5.0     500000.0     1985.0         500000.0
# 4  16.0  22          750000.0    9.0          NaN     1995.0        2400000.0
#
#    totalyears
# 0         7.0
# 1        24.0
# 2         3.0
# 3         8.0
# 4        10.0
#
# [5 rows x 34 columns]

# %%
for y in sorted(df['firstyear'].unique()):
    mask = (df['firstyear']==df['yearID']) & (df['firstyear']==y)
    print(y,"  = ",mask.sum(), "  na= ", df[mask]['firstsalary'].isna().sum())

df['lgID'].value_counts()
# Out:
# 1985.0   =  141   na=  21
# 1986.0   =  82   na=  12
# 1987.0   =  26   na=  3
# 1988.0   =  23   na=  5
# 1989.0   =  46   na=  10
# 1990.0   =  47   na=  7
# 1991.0   =  30   na=  4
# 1992.0   =  34   na=  4
# 1993.0   =  85   na=  13
# 1994.0   =  45   na=  6
# 1995.0   =  69   na=  13
# 1996.0   =  34   na=  3
# 1997.0   =  53   na=  12
# 1998.0   =  43   na=  2
# 1999.0   =  54   na=  6
# 2000.0   =  19   na=  3
# 2001.0   =  33   na=  9
# 2002.0   =  45   na=  6
# 2003.0   =  40   na=  4
# 2004.0   =  35   na=  2
# 2005.0   =  42   na=  5
# 2006.0   =  51   na=  8
# 2007.0   =  56   na=  5
# 2008.0   =  48   na=  8
# 2009.0   =  36   na=  3
# 2010.0   =  34   na=  5
# NL    3822
# AL    3571
# Name: lgID, dtype: int64

# %%
df[(df['firstyear']==df['yearID']) & (df['lgID']=='NL')].boxplot(column=['firstsalary'], by = ['yearID'], showfliers = False, figsize=(12,12))
df[(df['firstyear']==df['yearID']) & (df['lgID']=='AL')].boxplot(column=['firstsalary'], by = ['yearID'], showfliers = False, figsize=(12,12))

# %%
#每年開始 到結束的年限期
for y in sorted(df['firstyear'].unique()):
    mask = (df['firstyear']==y)
    #print(df[mask].groupby('playerID')['totalyears'].mean().value_counts().sort_index())
    df[mask].groupby('playerID')['totalyears'].mean().value_counts().sort_index().plot.bar()
    plt.title(str(y))
    plt.show()

# %% [markdown]
# # 計算起薪

# %%
# 不同公司給隨時間給予的起薪中位數 (1985不準，推測資料不完整)
df[(df['firstyear']==df['yearID']) & (df['lgID']=='NL')].groupby('yearID')['firstsalary'].median().plot()
df[(df['firstyear']==df['yearID']) & (df['lgID']=='AL')].groupby('yearID')['firstsalary'].median().plot()
plt.show()

NewColumns = ['NL_startsalary_by_year','AL_startsalary_by_year']
for t in NewColumns: df[t] = df['yearID'].copy()
    
a = df[(df['firstyear']==df['yearID']) & (df['lgID']=='NL')].groupby('yearID')['firstsalary'].median()
a[a.index==1985] = (a[a.index==1986].values+a[a.index==1987].values)*0.5
a = a.append(pd.Series([a[a.index==2010].values[0]*2-a[a.index==2009].values[0]], index=[2011]))
df['NL_startsalary_by_year'] = df['NL_startsalary_by_year'].map(a.to_dict())

b = df[(df['firstyear']==df['yearID']) & (df['lgID']=='AL')].groupby('yearID')['firstsalary'].median()
b[b.index==1985] = (b[b.index==1986].values+b[b.index==1987].values)*0.5
b = b.append(pd.Series([b[b.index==2010].values[0]*2-b[b.index==2009].values[0]], index=[2011]))
df['AL_startsalary_by_year'] = df['AL_startsalary_by_year'].map(b.to_dict())

a.plot()
b.plot()
plt.show()

# %%
def TeamDiff(dfx):
    dfx.boxplot(column=['firstsalary'], by = ['teamID'], showfliers = False, figsize=(12,12))
    plt.title(str(dfx['yearID'].iloc[0]))
    plt.axhline(dfx['NL_startsalary_by_year'].iloc[0], color= 'r')
    plt.axhline(dfx['AL_startsalary_by_year'].iloc[0], color= 'b')
    plt.show()
df[(df['firstyear']==df['yearID']) & (df['yearID']!=1985)].groupby(['yearID']).apply(TeamDiff)
#.boxplot(column=['firstsalary'], by = ['teamID'], showfliers = False, figsize=(60,60))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#分析team
def TeamDiffSum(dfx):
    tmp = dfx['{0}_startsalary_by_year'.format(dfx['lgID'].iloc[0])]
    return ((dfx['firstsalary']-tmp)/tmp).sum()
def TeamDiffCubicSum(dfx):
    tmp = dfx['{0}_startsalary_by_year'.format(dfx['lgID'].iloc[0])]
    return (((dfx['firstsalary']-tmp)/tmp)**2).sum()

NewColumns = ['Team_Sum','Team_CubicSum']
for t in NewColumns: df[t] = df['teamID'].copy()
    
#df[(df['firstyear']==df['yearID']) & (df['yearID']!=1985)].groupby(['teamID']).apply(TeamDiffSum)
df['Team_Sum']      = df['Team_Sum']     .map(df[(df['firstyear']==df['yearID']) & (df['yearID']!=1985)].groupby(['teamID']).apply(TeamDiffSum))
df['Team_CubicSum'] = df['Team_CubicSum'].map(df[(df['firstyear']==df['yearID']) & (df['yearID']!=1985)].groupby(['teamID']).apply(TeamDiffCubicSum))
df.head()
# Out:
#    id   playerID  yearID  stint teamID lgID   W  L   G  GS  ...  \
# 0   0  nelsoge01    1986      1    CHA   AL   6  6  54   1  ...
# 1   1  moyerja01    1997      1    SEA   AL  17  5  30  30  ...
# 2   2  thompbr01    2008      1    SLN   NL   6  3  26   6  ...
# 3   3  powerte01    1986      1    CIN   NL  10  6  56  10  ...
# 4   4  osunaan01    2003      1    NYA   AL   2  5  48   0  ...
#
#    salary_next_year  years  firstsalary  firstyear  salary_the_year  \
# 0          365000.0    4.0     240000.0     1985.0         240000.0
# 1         2000000.0   15.0      70000.0     1986.0              NaN
# 2          650000.0    0.0     400000.0     2006.0         414000.0
# 3          500000.0    5.0     500000.0     1985.0         500000.0
# 4          750000.0    9.0          NaN     1995.0        2400000.0
#
#    totalyears  NL_startsalary_by_year  AL_startsalary_by_year   Team_Sum  \
# 0         7.0                117518.5                140750.0  -0.653918
# 1        24.0                212500.0                208000.0   4.913768
# 2         3.0                426000.0                420000.0   3.038064
# 3         8.0                117518.5                140750.0   4.310306
# 4        10.0                330000.0                330000.0  61.016180
#
#    Team_CubicSum
# 0       1.598084
# 1       6.322251
# 2      15.460188
# 3       5.796661
# 4    1074.742629
#
# [5 rows x 38 columns]

# %%
#對team做 dummy
df = pd.get_dummies(df, columns = ["teamID", "lgID"])
df.columns
df.columns[df.dtypes == 'object']
# Out:
# Index(['playerID'], dtype='object')

# %%
from scipy import stats
from scipy.special import boxcox, inv_boxcox

df['start_salary_ratio'] = (df['salary_next_year'] - df['NL_startsalary_by_year']/2 - df['AL_startsalary_by_year']/2)/(df['NL_startsalary_by_year']/2 + df['AL_startsalary_by_year']/2)
mask = (df['firstyear']==df['yearID']) & (df['yearID']!=1985) & (df['start_salary_ratio'].notna())
minvalue = df[mask]['start_salary_ratio'].min()-1
print("Min=", minvalue)

a = df[mask]['start_salary_ratio']-minvalue
df.loc[mask,'start_salary_ratio'], boxcox_b = stats.boxcox(a.values)
print("boxcox_b=", boxcox_b)

plt.hist(df.loc[mask,'start_salary_ratio'], bins= 20)
plt.show()

xr= inv_boxcox(df.loc[mask,'start_salary_ratio'], boxcox_b)+minvalue
#print((xr==a.values).sum(), "  len=",mask.sum())
# Out:
# Min= -1.5160075657697318
# boxcox_b= -2.117775439286644

# %%
df.head()
print(df.shape)
print("起薪判定 須把參數'id', 'playerID', 'firstsalary', 'salary_next_year', 'totalyears', 'salary_the_year' 去除")
print("起薪判定 並以'start_salary_ratio' 作為target")
df.columns
# Out:
# (7393, 73)
# 起薪判定 須把參數'id', 'playerID', 'firstsalary', 'salary_next_year', 'totalyears', 'salary_the_year' 去除
# 起薪判定 並以'start_salary_ratio' 作為target
# Index(['id', 'playerID', 'yearID', 'stint', 'W', 'L', 'G', 'GS', 'CG', 'SHO',
#        'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp', 'ERA', 'IBB',
#        'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'salary_next_year', 'years',
#        'firstsalary', 'firstyear', 'salary_the_year', 'totalyears',
#        'NL_startsalary_by_year', 'AL_startsalary_by_year', 'Team_Sum',
#        'Team_CubicSum', 'teamID_ANA', 'teamID_ARI', 'teamID_ATL', 'teamID_BAL',
#        'teamID_BOS', 'teamID_CAL', 'teamID_CHA', 'teamID_CHN', 'teamID_CIN',
#        'teamID_CLE', 'teamID_COL', 'teamID_DET', 'teamID_FLO', 'teamID_HOU',
#        'teamID_KCA', 'teamID_LAA', 'teamID_LAN', 'teamID_MIL', 'teamID_MIN',
#        'teamID_ML4', 'teamID_MON', 'teamID_NYA', 'teamID_NYN', 'teamID_OAK',
#        'teamID_PHI', 'teamID_PIT', 'teamID_SDN', 'teamID_SEA', 'teamID_SFN',
#        'teamID_SLN', 'teamID_TBA', 'teamID_TEX', 'teamID_TOR', 'teamID_WAS',
#        'lgID_AL', 'lgID_NL', 'start_salary_ratio'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression

#train_data = df[(df['firstyear']==df['yearID']) & (df['yearID']!=1985)].drop(columns = ['id', 'playerID', 'totalyears', 'salary_the_year', 'firstsalary', 'start_salary_ratio'])
#target     = 'salary_next_year'

train_data = df[(df['firstyear']==df['yearID']) & (df['yearID']!=1985)].drop(columns = ['id', 'playerID', 'totalyears', 'salary_the_year', 'firstsalary', 'salary_next_year'])
#train_data = df[(df['firstyear']==df['yearID'])].drop(columns = ['id', 'playerID', 'totalyears', 'salary_the_year', 'firstsalary', 'salary_next_year'])
target     = 'start_salary_ratio'

train_data[['NL_startsalary_by_year', 'AL_startsalary_by_year']] = np.log1p(train_data[['NL_startsalary_by_year', 'AL_startsalary_by_year']])
test_data    = train_data[train_data[target].isna()].drop(columns = [target])
train_data_x = train_data[train_data[target].notna()].drop(columns = [target])
train_data_y = train_data[train_data[target].notna()][target]

other_params = {'learning_rate': 0.05, 'n_estimators': 1000, 'max_depth': 100, 'min_child_weight': 1, 'seed': 0,
'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0, 'reg_alpha': 0, 'reg_lambda': 1}
model = XGBRegressor(**other_params)

#model = RandomForestRegressor(n_estimators =10)
#model = LogisticRegression()
train_X, test_X, train_Y, test_Y = train_test_split(train_data_x, train_data_y, test_size=0.6)

model.fit(train_X, train_Y)
predict_train_y= model.predict(train_X)

score_train = metrics.r2_score(train_Y.values, predict_train_y)
print('train score=', score_train)
predict_test_y= model.predict(test_X)
score_test = metrics.r2_score(test_Y.values, predict_test_y)
print('test score =', score_test)

def MeasureMSE(test_data, test_predict_y, minvalue, boxcox_b):
    mask = test_data.index
    a    = (df.iloc[mask]['NL_startsalary_by_year']/2 + df.iloc[mask]['AL_startsalary_by_year']/2)*(1+inv_boxcox(test_predict_y,boxcox_b)+minvalue)
    #a    = (df.iloc[mask]['NL_startsalary_by_year']/2 + df.iloc[mask]['AL_startsalary_by_year']/2)*(1+test_predict_y**boxcox_b+minvalue)
    score= metrics.mean_absolute_error(df.iloc[mask]['salary_the_year'], a)
    print("MSE=",score)
    
MeasureMSE(test_Y, predict_test_y, minvalue, boxcox_b)    

plt.hist(predict_test_y)
plt.show()

plt.hist(test_Y)
plt.show()
# Out:
# C:\Users\Company\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [00:01:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# train score= 0.9999578065146029
# test score = 0.11302496923636407
# MSE= 129576.850207769

# %%
a = np.vstack((train_X.columns.values,model.feature_importances_)).T
sorted(a,key=lambda x: x[1], reverse=True)
# Out:
# [array(['teamID_BOS', 0.11095181107521057], dtype=object),
#  array(['teamID_ML4', 0.0718146562576294], dtype=object),
#  array(['teamID_KCA', 0.06413515657186508], dtype=object),
#  array(['teamID_TEX', 0.0548897311091423], dtype=object),
#  array(['teamID_CHA', 0.03803243488073349], dtype=object),
#  array(['Team_Sum', 0.03769408166408539], dtype=object),
#  array(['firstyear', 0.034498896449804306], dtype=object),
#  array(['GF', 0.029636187478899956], dtype=object),
#  array(['SO', 0.029318612068891525], dtype=object),
#  array(['teamID_CLE', 0.02677224949002266], dtype=object),
#  array(['Team_CubicSum', 0.025431038811802864], dtype=object),
#  array(['SV', 0.020954804494976997], dtype=object),
#  array(['IPouts', 0.020457753911614418], dtype=object),
#  array(['BFP', 0.018154766410589218], dtype=object),
#  array(['HBP', 0.017857201397418976], dtype=object),
#  array(['yearID', 0.017797544598579407], dtype=object),
#  array(['SHO', 0.0167496707290411], dtype=object),
#  array(['teamID_ATL', 0.016484389081597328], dtype=object),
#  array(['teamID_ARI', 0.01619281992316246], dtype=object),
#  array(['HR', 0.015982475131750107], dtype=object),
#  array(['teamID_BAL', 0.014799368567764759], dtype=object),
#  array(['BAOpp', 0.014180616475641727], dtype=object),
#  array(['teamID_LAN', 0.013915698044002056], dtype=object),
#  array(['BB', 0.013837899081408978], dtype=object),
#  array(['CG', 0.013339914381504059], dtype=object),
#  array(['R', 0.013232136145234108], dtype=object),
#  array(['W', 0.013074342161417007], dtype=object),
#  array(['teamID_CIN', 0.012609489262104034], dtype=object),
#  array(['WP', 0.012102480046451092], dtype=object),
#  array(['GS', 0.0117307398468256], dtype=object),
#  array(['ERA', 0.011513346806168556], dtype=object),
#  array(['IBB', 0.011203107424080372], dtype=object),
#  array(['AL_startsalary_by_year', 0.01100330613553524], dtype=object),
#  array(['G', 0.010940874926745892], dtype=object),
#  array(['H', 0.010726850479841232], dtype=object),
#  array(['BK', 0.009688379243016243], dtype=object),
#  array(['years', 0.00932975485920906], dtype=object),
#  array(['ER', 0.008828812278807163], dtype=object),
#  array(['teamID_SFN', 0.008445019833743572], dtype=object),
#  array(['teamID_NYN', 0.007938039489090443], dtype=object),
#  array(['teamID_SEA', 0.007765284273773432], dtype=object),
#  array(['teamID_SLN', 0.007747138850390911], dtype=object),
#  array(['L', 0.007621917873620987], dtype=object),
#  array(['NL_startsalary_by_year', 0.006989126093685627], dtype=object),
#  array(['teamID_DET', 0.005473866127431393], dtype=object),
#  array(['teamID_SDN', 0.00542328879237175], dtype=object),
#  array(['teamID_HOU', 0.0048827254213392735], dtype=object),
#  array(['teamID_CAL', 0.004748588427901268], dtype=object),
#  array(['teamID_NYA', 0.004292213823646307], dtype=object),
#  array(['teamID_FLO', 0.004110490437597036], dtype=object),
#  array(['teamID_CHN', 0.003996750805526972], dtype=object),
#  array(['teamID_OAK', 0.0036273314617574215], dtype=object),
#  array(['teamID_PIT', 0.0029720186721533537], dtype=object),
#  array(['lgID_AL', 0.0022907431703060865], dtype=object),
#  array(['teamID_MIN', 0.002282331231981516], dtype=object),
#  array(['teamID_MON', 0.001855048118159175], dtype=object),
#  array(['lgID_NL', 0.0018527983920648694], dtype=object),
#  array(['teamID_TBA', 0.0013919823104515672], dtype=object),
#  array(['teamID_TOR', 0.0012928416253998876], dtype=object),
#  array(['teamID_ANA', 0.0010981238447129726], dtype=object),
#  array(['teamID_PHI', 0.000875077850650996], dtype=object),
#  array(['teamID_COL', 0.0008104267180897295], dtype=object),
#  array(['stint', 0.0003393673396203667], dtype=object),
#  array(['teamID_MIL', 1.4033213119546417e-05], dtype=object),
#  array(['teamID_LAA', 0.0], dtype=object),
#  array(['teamID_WAS', 0.0], dtype=object)]

# %%
a = model.get_booster().get_score(importance_type='weight')
sorted([[key,value] for key, value in a.items()],key=lambda x: x[1], reverse=True)
# Out:
# [['yearID', 2788],
#  ['W', 1545],
#  ['G', 1471],
#  ['L', 1240],
#  ['ERA', 1156],
#  ['Team_Sum', 905],
#  ['BB', 844],
#  ['BAOpp', 827],
#  ['IPouts', 804],
#  ['H', 758],
#  ['HR', 735],
#  ['SO', 711],
#  ['ER', 612],
#  ['GS', 574],
#  ['SV', 562],
#  ['IBB', 552],
#  ['years', 540],
#  ['Team_CubicSum', 521],
#  ['GF', 499],
#  ['WP', 466],
#  ['HBP', 432],
#  ['CG', 320],
#  ['BK', 290],
#  ['teamID_KCA', 271],
#  ['R', 246],
#  ['BFP', 208],
#  ['firstyear', 199],
#  ['AL_startsalary_by_year', 169],
#  ['teamID_OAK', 161],
#  ['SHO', 145],
#  ['NL_startsalary_by_year', 138],
#  ['lgID_AL', 101],
#  ['teamID_FLO', 95],
#  ['teamID_MON', 81],
#  ['teamID_SFN', 79],
#  ['teamID_ANA', 66],
#  ['teamID_SDN', 61],
#  ['teamID_ATL', 57],
#  ['teamID_DET', 57],
#  ['teamID_BAL', 51],
#  ['teamID_TBA', 49],
#  ['teamID_PIT', 45],
#  ['teamID_TEX', 36],
#  ['teamID_SEA', 34],
#  ['teamID_LAN', 33],
#  ['teamID_CLE', 30],
#  ['stint', 29],
#  ['teamID_MIN', 27],
#  ['lgID_NL', 26],
#  ['teamID_ML4', 21],
#  ['teamID_SLN', 21],
#  ['teamID_CAL', 21],
#  ['teamID_TOR', 18],
#  ['teamID_CIN', 16],
#  ['teamID_CHN', 15],
#  ['teamID_NYN', 12],
#  ['teamID_NYA', 12],
#  ['teamID_HOU', 10],
#  ['teamID_COL', 9],
#  ['teamID_PHI', 9],
#  ['teamID_BOS', 7],
#  ['teamID_CHA', 5],
#  ['teamID_ARI', 3],
#  ['teamID_MIL', 2]]

# %%
def MeasureMSE(test_data, test_predict_y, minvalue):
    mask = test_data.index
    a    = (df.iloc[mask]['NL_startsalary_by_year']/2 + df.iloc[mask]['AL_startsalary_by_year']/2)*(1+test_predict_y**5+minvalue)
    score= metrics.mean_absolute_error(df.iloc[mask]['salary_the_year'], a)
    print("MSE=",score)

# %%
a = pd.concat([pd.Series(test_Y.values),pd.Series(predict_test_y)],axis=1)
a['diff'] = abs(a[0]-a[1])
a[a['diff']>0.5]
# Out:
#             0         1      diff
# 47   1.422854  0.907263  0.515592
# 95   0.000000  0.686472  0.686472
# 134  0.000000  0.699783  0.699783
# 141  1.488953  0.939466  0.549487
# 240  1.337000  0.769961  0.567039
# 255  1.907802  0.934735  0.973067
# 272  1.813043  1.007927  0.805117
# 292  0.887038  1.394886  0.507849
# 471  0.000000  0.634878  0.634878

# %%
a = train_data['start_salary_ratio'].values

print(np.min((a-np.min(a))))
#plt.hist((a-np.min(a))**0.15)
df['start_salary_ratio'].isna().sum()
#len(df[(df['start_salary_ratio']<10) | (df['start_salary_ratio'].isna())])
len(df[(df['start_salary_ratio']<10)])
# Out:
# nan
# 4777

# %%
print(np.max(predict_test_y))
print(np.min(predict_test_y))
plt.hist(predict_test_y)
plt.show()

plt.hist(test_Y)
plt.show()
# Out:
# 1.3810103
# 0.691298

# %%
print(train_X.columns)
train_X['start_salary_ratio']
# Out:
# Index(['yearID', 'stint', 'W', 'L', 'G', 'GS', 'CG', 'SHO', 'SV', 'IPouts',
#        'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp', 'ERA', 'IBB', 'WP', 'HBP', 'BK',
#        'BFP', 'GF', 'R', 'years', 'firstyear', 'NL_startsalary_by_year',
#        'AL_startsalary_by_year', 'Team_Sum', 'Team_CubicSum',
#        'start_salary_ratio', 'teamID_ANA', 'teamID_ARI', 'teamID_ATL',
#        'teamID_BAL', 'teamID_BOS', 'teamID_CAL', 'teamID_CHA', 'teamID_CHN',
#        'teamID_CIN', 'teamID_CLE', 'teamID_COL', 'teamID_DET', 'teamID_FLO',
#        'teamID_HOU', 'teamID_KCA', 'teamID_LAA', 'teamID_LAN', 'teamID_MIL',
#        'teamID_MIN', 'teamID_ML4', 'teamID_MON', 'teamID_NYA', 'teamID_NYN',
#        'teamID_OAK', 'teamID_PHI', 'teamID_PIT', 'teamID_SDN', 'teamID_SEA',
#        'teamID_SFN', 'teamID_SLN', 'teamID_TBA', 'teamID_TEX', 'teamID_TOR',
#        'teamID_WAS', 'lgID_AL', 'lgID_NL'],
#       dtype='object')
# 2137   -0.046915
# 653    -0.252747
# 4601   -0.035088
# 5303   -0.178082
# 1752   -0.086022
#           ...
# 5801    0.001927
# 4502    0.052632
# 5416    0.260745
# 1874   -0.037249
# 2953    3.735306
# Name: start_salary_ratio, Length: 380, dtype: float64

# %%
test_1 = test_X.copy()
test_1['pre_salary']=np.exp(predict_test_y)-1

test_2 = train_X.copy()
test_2['pre_salary']=np.exp(predict_train_y)-1

test_3 = train_data_x.copy()
test_3['pre_salary']=np.exp(train_data_y)-1

# %%
test_1.boxplot(column=['pre_salary'], by = ['yearID'], showfliers = False, figsize=(12,12))
test_2.boxplot(column=['pre_salary'], by = ['yearID'], showfliers = False, figsize=(12,12))
test_3.boxplot(column=['pre_salary'], by = ['yearID'], showfliers = False, figsize=(12,12))
train_data.boxplot(column=['salary_next_year'], by = ['yearID'], showfliers = False, figsize=(12,12))

# %%
df[df[['NL_startsalary_by_year', 'AL_startsalary_by_year']].isna()]
# Out:
#       id playerID  yearID  stint   W   L   G  GS  CG  SHO  ...  teamID_SDN  \
# 0    NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# 1    NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# 2    NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# 3    NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# 4    NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# ...   ..      ...     ...    ...  ..  ..  ..  ..  ..  ...  ...         ...
# 1104 NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# 1105 NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# 1106 NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# 1107 NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
# 1108 NaN      NaN     NaN    NaN NaN NaN NaN NaN NaN  NaN  ...         NaN
#
#       teamID_SEA  teamID_SFN  teamID_SLN  teamID_TBA  teamID_TEX  teamID_TOR  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 1104         NaN         NaN         NaN         NaN         NaN         NaN
# 1105         NaN         NaN         NaN         NaN         NaN         NaN
# 1106         NaN         NaN         NaN         NaN         NaN         NaN
# 1107         NaN         NaN         NaN         NaN         NaN         NaN
# 1108         NaN         NaN         NaN         NaN         NaN         NaN
#
#       teamID_WAS  lgID_AL  lgID_NL
# 0            NaN      NaN      NaN
# 1            NaN      NaN      NaN
# 2            NaN      NaN      NaN
# 3            NaN      NaN      NaN
# 4            NaN      NaN      NaN
# ...          ...      ...      ...
# 1104         NaN      NaN      NaN
# 1105         NaN      NaN      NaN
# 1106         NaN      NaN      NaN
# 1107         NaN      NaN      NaN
# 1108         NaN      NaN      NaN
#
# [7393 rows x 72 columns]

# %%
'''
4973	ueharko01	2009	5000000.0	426750.0	10.740534
2278	irabuhi01	1997	2925000.0	212500.0	12.912010
4832	baezda01	2002	5125000.0	325000.0	14.769231
4659	howest01	1992	2500000.0	152000.0	15.556291
46	matsuda01	2007	8333333.0	405250.0	19.074274
4658	contrjo01	2003	8500000.0	330000.0	24.757576
4429	kurodhi01	2008	12433333.0	426000.0	28.393222
'''

mask = (df['playerID']=='matsuda01').values
df.iloc[mask,:].sort_values(by='yearID')[['teamID', 'lgID', 'yearID','salary_next_year']]
# Out:
#      teamID lgID  yearID  salary_next_year
# 46      BOS   AL    2007         8333333.0
# 209     BOS   AL    2008         8333333.0
# 5477    BOS   AL    2009         8333333.0
# 562     BOS   AL    2010        10333333.0
# 3943    BOS   AL    2011        10333333.0

# %%
df[(df['teamID']=="BOS") & (df['lgID']=="AL")].sort_values(by=['playerID','yearID'])[['playerID', 'teamID', 'lgID', 'yearID','salary_next_year']].to_csv('Result.csv')

# %%
(df['playerID']=='nelsoge01').sum()
# Out:
# 7

# %%
x=50
np.exp(np.log1p(x))-1
# Out:
# 50.0

# %%
def top(df,n=5,column='yearID'):
    return df.sort_values(by=column)[-n:]

df.groupby('playerID').apply(top)
